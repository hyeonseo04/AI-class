# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# 데이터 로드
path = '/content/drive/MyDrive/Colab Notebooks/AI_class/2_week/diabetes.csv'
df = pd.read_csv(path)

# %%
# X, y 분리
y = df['Outcome']
X = df.drop('Outcome', axis=1)

# %%
# 학습 / 테스트 분리 (75% / 25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
# ── 1. Logistic Regression ──────────────────────────
clf_lr = LogisticRegression(random_state=0, max_iter=1000)
clf_lr.fit(X_train, y_train)
pred_lr = clf_lr.predict(X_test)

# ── 2. Decision Tree ────────────────────────────────
clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)
pred_dt = clf_dt.predict(X_test)

# ── 3. Random Forest ────────────────────────────────
clf_rf = RandomForestClassifier(random_state=0, n_estimators=100)
clf_rf.fit(X_train, y_train)
pred_rf = clf_rf.predict(X_test)

# %%
# ── 결과 출력 ────────────────────────────────────────
models = {
    "Logistic Regression": pred_lr,
    "Decision Tree":       pred_dt,
    "Random Forest":       pred_rf,
}

for name, pred in models.items():
    print(f"\n--- {name} ---")
    print(f"Accuracy : {accuracy_score(y_test, pred):.4f}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_test, pred)}")
# Out:
# --- Logistic Regression ---
# Accuracy : 0.7969
# Confusion Matrix:
# [[117  13]
#  [ 26  36]]
#
# --- Decision Tree ---
# Accuracy : 0.7188
# Confusion Matrix:
# [[102  28]
#  [ 26  36]]
#
# --- Random Forest ---
# Accuracy : 0.7708
# Confusion Matrix:
# [[116  14]
#  [ 30  32]]

# %%
# [removed for security]

# %%
# !cd /content/AI-class-repo && git add . && git commit -m "Add 2_week files (clean)" && git push
